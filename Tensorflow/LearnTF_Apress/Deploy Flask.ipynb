# %%
 # !pip install colabcode

# %%
from colabcode import ColabCode
ColabCode(port=10000, password="password123")
# Out:
# Code Server can be accessed on: https://002b6038dd2d.ngrok.io
# [2020-10-17T14:26:21.142Z] info  Using user-data-dir ~/.local/share/code-server
# [2020-10-17T14:26:21.148Z] info  code-server 3.6.0 a4a03c14922ccaec2a9ff8d1b7b2af8522a4214d
# [2020-10-17T14:26:21.148Z] info  Using config file ~/.config/code-server/config.yaml
# [2020-10-17T14:26:21.153Z] info  HTTP server listening on http://127.0.0.1:10000
# [2020-10-17T14:26:21.153Z] info      - Using password from $PASSWORD
# [2020-10-17T14:26:21.153Z] info      - To disable use `--auth none`
# [2020-10-17T14:26:21.154Z] info    - Not serving HTTPS
