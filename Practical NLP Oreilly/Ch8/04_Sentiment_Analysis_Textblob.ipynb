# %% [markdown]
# In this notebook we demonstrate a basic text classifier using [Textblob.](https://textblob.readthedocs.io/en/dev/) .

# %%
#load the dataset
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Data/NLP/Practical_NLP_Oreilly/Chap8/sts_gold_tweet.csv",error_bad_lines=False,delimiter=";")
print(df.columns)

#make a list of all the tweets
tweets_text_collection = list(df['tweet'])
# Out:
# Index(['id', 'polarity', 'tweet'], dtype='object')

# %%
df
# Out:
#               id  polarity                                              tweet
# 0     1467933112         0  the angel is going to miss the athlete this we...
# 1     2323395086         0  It looks as though Shaq is getting traded to C...
# 2     1467968979         0     @clarianne APRIL 9TH ISN'T COMING SOON ENOUGH
# 3     1990283756         0  drinking a McDonalds coffee and not understand...
# 4     1988884918         0  So dissapointed Taylor Swift doesnt have a Twi...
# ...          ...       ...                                                ...
# 2029  1468049681         0  A king sized bed is nice but sad and lonely wi...
# 2030  2195475499         0  @breannalovesjb hurry up home!!!!! im dying wi...
# 2031  1996172176         0  @jordanhowell lol only a PSP, had a game boy b...
# 2032  2016105580         4  Good morning everyone!  It is such a beautiful...
# 2033  2186977170         4  hey guess was @magicmanil the Lakers won and K...
#
# [2034 rows x 3 columns]

# %%
df.polarity.value_counts()
# Out:
# 0    1402
# 4     632
# Name: polarity, dtype: int64

# %%
tweets_text_collection[:3]
# Out:
# ['the angel is going to miss the athlete this weekend ',
#  "It looks as though Shaq is getting traded to Cleveland to play w/ LeBron... Too bad for Suns' fans. The Big Cactus is no more ",
#  "@clarianne APRIL 9TH ISN'T COMING SOON ENOUGH "]

# %% [markdown]
# We’ll move forward by building a system for sentiment analysis and
# setting up a baseline. For this, we’ll use TextBlob [22], which is a
# Python-based NLP toolkit built on top of NLTK and Pattern. It
# comes with an array of modules for text processing, text mining, and
# text analysis. All it takes is five lines of code to get a basic
# sentiment classifier:

# %% [markdown]
# This will give us polarity and subjectivity values of each of the
# tweets in the corpus. Polarity is a value between [–1.0, 1.0] and tells
# how positive or negative the text is. Subjectivity is within the range
# [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.

# %%
from textblob import TextBlob
 
for tweet_text in tweets_text_collection:
    print('tweet_text: ',tweet_text)
    analysis = TextBlob(tweet_text)
    print('analysis.sentiment: ',analysis.sentiment)#analyse the sentitment
    #Polarity is a value between [-1.0, 1.0] and tells how positive or negative the text is. 
    #Subjectivity is within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.
    print("-"*20)
    # break
# Out:
# Streaming output truncated to the last 5000 lines.
# --------------------
# tweet_text:  @OfficialRandL when is the announcement? i stayed up late last night
# analysis.sentiment:  Sentiment(polarity=-0.15, subjectivity=0.3333333333333333)
# --------------------
# tweet_text:  Time to break out Howard's puppet! Bye bye LeBron!
# analysis.sentiment:  Sentiment(polarity=0.0, subjectivity=0.0)
# --------------------
# tweet_text:  I want to see king blues at the &quot;electric ballroom&quot; in london but ill get crushed.  I hate being a 14 year old that looks like an 8 yr old
# analysis.sentiment:  Sentiment(polarity=-0.23999999999999994, subjectivity=0.4800000000000001)
# --------------------
# tweet_text:  @StarChile.....ahhh.....alright. Thanks. Congrat's on your team's win today
# analysis.sentiment:  Sentiment(polarity=0.5, subjectivity=0.30000000000000004)
# --------------------
# tweet_text:  Down with a nasty fever
# ...

# %% [markdown]
# There are many more features in textblob you can refer the official documentation for them.
